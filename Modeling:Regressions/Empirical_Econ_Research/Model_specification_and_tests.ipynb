# %% [markdown]
# - cci - Consumer Confidence Index (CCI) - a monthly survey by The Conference Board that measures how optimistic or pessimistic consumers are regarding financial situations, both current and expected. Administered via survery. Leading indicator reflecting U.S. economic conditions, major purchases, consumer view of economy, business conditions, and labor market currently and over the next six months. Two parts of this index is the current expectations and future expectations </br>
#     -1985=100 </br>
#             -- cci > 100: consumers are optimistic = more spending</br>
#             -- cci < 100: consumers are optimistic = less spending</br>
#             -- cci < 100: consumers are optimistic = less spending</br>
# Released on the last Tuesday of every month.

# %% [markdown]
# - cci_cur - CCI Current Expectations component

# %% [markdown]
# - cci_exp - CCI Future Expectations component

# %% [markdown]
# - umsent - Michigan Consumer Sentiment Index (MCSI) -- a monthly report of consumer confidence levels in the U.S. conducted by the UMICH. Survey results collected via telephone interviews. Also a lead indicator. Differs from CCI in that CCI places more weight on employment and labor market while MCSI focuses primarily on households and future expectations is at 12 months instead of 6 months.</br>
#         - same index number scale</br>
# Released on the second Friday of each month.

# %% [markdown]
# - umsent_cur - MCSI Current Expectations component

# %% [markdown]
# - umsent_exp - MCSI Future Expectations component

# %% [markdown]
# - ism_man - ISM Manufacturing Index or Manufacturing Purchasing Managers' Index (PMI) -- reflects the demand level of goods  by the amount of ordering activity from factories. Index of new orders, production, employment, supplier deliveries, and inventories. </br>
#         -- Manufacturing PMI > 50 = expanding manufacturing segment compared to last month</br>
#         -- Manufacturing PMI < 50 = contracting "   "</br>
# This is released on the first business day of each month, so can influence CCI and MCSI.

# %% [markdown]
# - ism_non - ISM Non-Manufacturing Index or Non-Manufacturing Purchings Managers' Index (PMI) -- surveys purchasing and supply executives, caputring 15 different (service) industries. Indexes business acitivity, new ordres, employment trends, inventories, and prices.</br>
#         -- Finance and Insurance, Agriculture, Retail Trade, Ulilities, Educational Services, etcs.</br>
# Released on the third business day of the month.

# %% [markdown]
# OlS Assumptions:</br>
# [1] The regression is linear.</br>
# [2] Random observations.</br>
# [3] The conditional mean should be zero.</br>
# [4] There is no multi-collinearity.</br>
# [5] There is homoscedasticity and no autocorrelation.</br>
# [6] (Optional) Error terms should be naturally distributed.</br>

# %%
# libraries 
import numpy as np
import statsmodels.api as sm
import pandas as pd
import statsmodels.formula.api as smf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.stattools import adfuller
from statsmodels.compat import lzip
import statsmodels.stats.api as sms
from sklearn.linear_model import LinearRegression
from statsmodels.stats.diagnostic import het_white
from statsmodels.graphics.api import interaction_plot, abline_plot
from statsmodels.stats.anova import anova_lm
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats
import statsmodels
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Checking data from cleaning before continuing on

# %%
# data
df = pd.read_csv('cur-us_owid_covid_monthly.csv')
pd.set_option('display.max_columns', None)
df = df.dropna()
df.shape[0]
#df.head(5)
# Out:
# 300

# %%
x_columns = [ 'total_cases', 'stringency_index', 'umsent', 'cci_lag1']
y = df['cci']

# %%
x = df[x_columns] 
x = sm.add_constant(x)
summary = sm.OLS(y,x).fit(cov_type='HC3')
print(summary.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cci   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     1864.
# Date:                Sat, 12 Nov 2022   Prob (F-statistic):          6.14e-208
# Time:                        20:50:22   Log-Likelihood:                -923.57
# No. Observations:                 300   AIC:                             1857.
# Df Residuals:                     295   BIC:                             1876.
# Df Model:                           4
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              -27.2104      3.619     -7.520      0.000     -34.303     -20.118
# total_cases       2.292e-07    5.2e-08      4.410      0.000    1.27e-07    3.31e-07
# stringency_index     0.0477      0.040      1.179      0.238      -0.032       0.127
# umsent               0.6187      0.073      8.504      0.000       0.476       0.761
# cci_lag1             0.7191      0.033     21.765      0.000       0.654       0.784
# ==============================================================================
# Omnibus:                        5.150   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                5.976
# Skew:                          -0.160   Prob(JB):                       0.0504
# Kurtosis:                       3.613   Cond. No.                     1.20e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 1.2e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# [1] The regression is linear. (Displaying more than one way.)

# %%
sy = smf.ols('cci ~ total_cases + stringency_index + VaxFull**2 + cci_lag1:umsent', df)
mo = sy.fit(cov_type='HC3')
print(mo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cci   R-squared:                       0.956
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     1336.
# Date:                Sat, 12 Nov 2022   Prob (F-statistic):          1.44e-187
# Time:                        17:34:55   Log-Likelihood:                -951.16
# No. Observations:                 300   AIC:                             1912.
# Df Residuals:                     295   BIC:                             1931.
# Df Model:                           4
# Covariance Type:                  HC3
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           28.0754      1.059     26.518      0.000      26.000      30.151
# total_cases       1.921e-07   6.93e-08      2.772      0.006    5.63e-08    3.28e-07
# stringency_index     0.0944      0.035      2.689      0.007       0.026       0.163
# VaxFull              0.1387      0.070      1.994      0.046       0.002       0.275
# cci_lag1:umsent      0.0078      0.000     71.317      0.000       0.008       0.008
# ==============================================================================
# Omnibus:                        2.091   Durbin-Watson:                   1.430
# Prob(Omnibus):                  0.352   Jarque-Bera (JB):                1.789
# Skew:                          -0.158   Prob(JB):                        0.409
# Kurtosis:                       3.208   Cond. No.                     3.64e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
# [2] The condition number is large, 3.64e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
influencers = sm.graphics.influence_plot(mo)

# cooks distance
cooksd = mo.get_influence().cooks_distance[0]

#df to obtain n
n = len(df['cci_lag1'])

# calculate critical d
critical_d = 4/n
print(("Cook's Criticl Distance is: ", critical_d))

# IDs potential outliers w/ leverage
outl_d = cooksd > critical_d
# above 0.5, worth a look at it b/c it may be influential
print(df.index[outl_d],'/n',cooksd[outl_d])
# Out:
# ("Cook's Criticl Distance is: ", 0.013333333333333334)
# Int64Index([435, 501, 505, 507, 508, 535, 538, 637, 638, 639, 641, 644, 647,
#             649, 650, 653, 659, 662, 663, 665],
#            dtype='int64') /n [0.02305275 0.06080088 0.01794328 0.02211994 0.02240229 0.01361369
#  0.01543799 0.05096502 0.84663156 0.57397319 0.11281392 0.11053513
#  0.01605484 0.02235358 0.09161816 0.026452   0.02437565 0.04119751
#  0.04707446 0.03440936]

# %%
fig =plt.figure(figsize=(12,8))
# CCPR Plot displays outliers and linearity 
fig = sm.graphics.plot_ccpr_grid(mo, fig=fig)

# %%
# Checking data quality
fig = plt.figure(figsize= (5, 5))
ax = fig.add_subplot(111)

normality_plot, stat = stats.probplot(mo.resid, plot= plt, rvalue= True)
ax.set_title("Probability plot of model residual's", fontsize= 15)
ax.set

plt.show()

# %%
#define figure size
fig = plt.figure(figsize=(25,15))

#produce regression plots
# of y on one predictor variable with different graphs
# fig = sm.graphics.plot_regress_exog(mo, 'cci_lag1', fig=fig)
fig = sm.graphics.plot_partregress_grid(mo, fig=fig)
fig.tight_layout(pad=1.0)
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %% [markdown]
# - 'Y and Fitted vs X' and 'Residuals vs fitted' -- checks linear assumptions of linearity, normality, constant variance (violated-hetero, makes cone shape), and independence. </br>
# https://analyse-it.com/docs/user-guide/fit-model/linear/residual-plot

# %% [markdown]
# - Partial Regression Plot -- checks inluential points and linearity

# %% [markdown]
# - CCPR Plot -- checks inluential points, relationship between a regressor and response </br>
# by taking into account the other independent variables. The line is if x was highly correlated with any </br>
# of the other independent variables.

# %%
# scatterplot via seaborn and not matplot
mo.fittedvalues
Y_max = y.max()
Y_min = x.min()

ax = sns.scatterplot(x=mo.fittedvalues, y=y)
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Predicted value of CCI")
ax.set_ylabel("Observed value of CCI")

X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [185], in <cell line: 7>()
#       4 Y_min = x.min()
#       6 ax = sns.scatterplot(x=mo.fittedvalues, y=y)
# ----> 7 ax.set(ylim=(Y_min, Y_max))
#       8 ax.set(xlim=(Y_min, Y_max))
#       9 ax.set_xlabel("Predicted value of CCI")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:117, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     109 if not hasattr(cls.set, '_autogenerated_signature'):
#     110     # Don't overwrite cls.set if the subclass or one of its parents
#     111     # has defined a set method set itself.
#     112     # If there was no explicit definition, cls.set is inherited from
#     113     # the hierarchy of auto-generated set methods, which hold the
#     114     # flag _autogenerated_signature.
#     115     return
# --> 117 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     118 cls.set.__name__ = "set"
#     119 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1194, in Artist.set(self, **kwargs)
#    1190 def set(self, **kwargs):
#    1191     # docstring and signature are auto-generated via
#    1192     # Artist._update_set_signature_and_docstring() at the end of the
#    1193     # module.
# -> 1194     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1186, in Artist._internal_update(self, kwargs)
#    1179 def _internal_update(self, kwargs):
#    1180     """
#    1181     Update artist properties without prenormalizing them, but generating
#    1182     errors as if calling `set`.
#    1183
#    1184     The lack of prenormalization is to maintain backcompatibility.
#    1185     """
# -> 1186     return self._update_props(
#    1187         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1188         "{prop_name!r}")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1162, in Artist._update_props(self, props, errfmt)
#    1159             if not callable(func):
#    1160                 raise AttributeError(
#    1161                     errfmt.format(cls=type(self), prop_name=k))
# -> 1162             ret.append(func(v))
#    1163 if ret:
#    1164     self.pchanged()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:3925, in _AxesBase.set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    3923         raise TypeError("Cannot pass both 'top' and 'ymax'")
#    3924     top = ymax
# -> 3925 return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py:1136, in Axis._set_lim(self, v0, v1, emit, auto)
#    1133         _api.warn_external(f"Attempt to set non-positive {name}lim on "
#    1134                            f"a log-scaled axis will be ignored.")
#    1135         v1 = old1
# -> 1136 if v0 == v1:
#    1137     _api.warn_external(
#    1138         f"Attempting to set identical low and high {name}lims "
#    1139         f"makes transformation singular; automatically expanding.")
#    1140 reverse = bool(v0 > v1)  # explicit cast needed for python3.8+np.bool_.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:1537, in NDFrame.__nonzero__(self)
#    1535 @final
#    1536 def __nonzero__(self):
# -> 1537     raise ValueError(
#    1538         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# If linearity is not satisfied:
# - https://www.quality-control-plan.com/StatGuide/linreg_ass_viol.htm

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# [3] The conditional mean should be zero.</br>

# %%
# The really small zero is from approximation, we can assume that the expecter resid mean is 0.
mo.resid.mean()
# Out:
# 3.386920373789811e-14

# %% [markdown]
# Possible reasons if not satisfied:
# - Omitted Variables
# - Measurement Errors
# - Non-Linearities or unpredicted effects

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# [4] There is no multi-collinearity.

# %%
# VIF - measuring strength of correlation with between the predictors, checking for multicollinearity
# between pedictors, If no features are correlated, than all values would be 1. 
# Rule of thumb for removal, VIF larger than 5, or 10.
x_columns = df[[ 'total_cases_stan_start_start', 'stringency_index_stan_start_start', 'umsent_stan', 'cci_lag1_stan']]
x = sm.add_constant(x_columns)
y = df['cci']

# %%
dxf2 = pd.DataFrame()

dxf2['feature'] = x_columns.columns

dxf2['VIF'] = [variance_inflation_factor(x_columns.values, i) 
              for i in range(x_columns.shape[1])]


print(dxf2)
# Out:
#                              feature       VIF
# 0       total_cases_stan_start_start  1.672482
# 1  stringency_index_stan_start_start  1.654571
# 2                        umsent_stan  2.603876
# 3                      cci_lag1_stan  2.584542

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# [5] There is homoscedasticity (equal variance) and no autocorrelation.</br>

# %%
# Breusch-Pagan test
names = ['Lagrange multiplier statistic', 'p-value',
         'f-value', 'f p-value']
 
# test result
test_result = sms.het_breuschpagan(mo.resid, mo.model.exog)
 
lzip(names, test_result)
# Looking for p-values at or below significance level
# Out:
# [('Lagrange multiplier statistic', 44.67248562293822),
#  ('p-value', 4.65076007395075e-09),
#  ('f-value', 12.90341083188673),
#  ('f p-value', 1.0778554035942553e-09)]

# %%
# Durbin Watson - is < 1, maybe concern. small values of d indicate successive error terms
# are positively correlated. Tests or no lag one, correlation. d > 2, err terms are negatively corrarelated.
# around 2 is symmetric.
sm.stats.durbin_watson(mo.resid)
# Out:
# 1.962599454168412

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# [6] (Optional) Error terms should be naturally distributed.</br>

# %% [markdown]
# Jarque-Bera statistics. p=value > 0.05 reflects normal distribution.

# %%
# Checking for Stationarity, making sure that the mean, variance, and autocorrelation structure
# doesn't change over time

df_stationarityTest = adfuller(df['cci'], autolag='AIC')
print('p-value: ', df_stationarityTest[1])
# Out:
# p-value:  0.27891037351945935

# %%
# checking the assumption of normality(normal distribution--homoskedasticity
#      data skew and model fit
from scipy import stats

stats.probplot(mo.resid, dist="norm", plot= plt)
plt.title("cci ~ total_cases_stan_start_start + stringency_index_stan_start_start + umsent_stan + cci_lag1_stan - Residuals Q-Q Plot")

#Saving plot as a png
#plt.savefig("Model1_Resid_qqplot.png")
# Out:
# Text(0.5, 1.0, 'cci ~ total_cases_stan_start_start + stringency_index_stan_start_start + umsent_stan + cci_lag1_stan - Residuals Q-Q Plot')

# %%
from scipy import stats

stats.probplot(summary1.resid, dist="norm", plot= plt)
plt.title("cci ~ total_cases + cci_lag1 + ism-man - Residuals Q-Q Plot")

#Saving plot as a png
#plt.savefig("Model1_Resid_qqplot.png")
# Out:
# Text(0.5, 1.0, 'cci ~ total_cases + cci_lag1 + ism-man - Residuals Q-Q Plot')

# %%
table = sm.stats.anova_lm(mo, typ=1)
print(table)
# Out:
#                                       df         sum_sq        mean_sq  \
# total_cases_stan_start_start         1.0      27.239033      27.239033
# stringency_index_stan_start_start    1.0     662.501546     662.501546
# umsent_stan                          1.0  149317.388488  149317.388488
# cci_lag1_stan                        1.0   67854.878004   67854.878004
# Residual                           295.0   10465.353296      35.475774
#
#                                              F         PR(>F)
# total_cases_stan_start_start          0.767821   3.816050e-01
# stringency_index_stan_start_start    18.674760   2.121515e-05
# umsent_stan                        4208.995947  1.186621e-176
# cci_lag1_stan                      1912.710297  5.819321e-131
# Residual                                   NaN            NaN

# %%
pg = df.corr()
# pg = pg.to_csv('resid_q-q_plot.csv', encoding='utf-8')
pg
# Out:
#                                    total_cases  new_cases  new_cases_smoothed  \
# total_cases                           1.000000   0.731918            0.675118
# new_cases                             0.731918   1.000000            0.916267
# new_cases_smoothed                    0.675118   0.916267            1.000000
# total_deaths                          0.983190   0.760064            0.698959
# new_deaths                            0.646423   0.857942            0.748111
# positive_rate                         0.633434   0.829708            0.856726
# stringency_index                      0.595817   0.700117            0.629771
# cci                                   0.094413   0.045618            0.045807
# cci_cur                               0.152775   0.074558            0.070557
# cci_exp                              -0.035227  -0.018546           -0.010404
# umsent                               -0.329655  -0.279644           -0.248900
# umsent_cur                           -0.387146  -0.328161           -0.292073
# umsent_exp                           -0.269706  -0.228921           -0.203722
# ism_man                               0.253471   0.244688            0.229843
# ism_non                               0.280734   0.237940            0.208248
# cci_lag1                              0.098416   0.060226            0.059576
# cci_lag2                              0.100656   0.080145            0.072448
# cci_lag3                              0.099427   0.084317            0.073124
# cci_lag4                              0.098822   0.081383            0.070697
# cci_lag5                              0.099753   0.089600            0.077625
# cci_lag6                              0.098045   0.103990            0.093451
# cci_lag7                              0.094816   0.098536            0.098789
# cci_lag8                              0.093872   0.085311            0.087233
# total_cases_lag1                      0.995610   0.678265            0.613095
# total_cases_lag2                      0.987893   0.667050            0.597711
# total_deaths_lag1                     0.985699   0.742266            0.680348
# total_deaths_lag2                     0.986382   0.736626            0.673357
# VaxFull                               0.955868   0.679553            0.629569
# umsent_stan                          -0.387146  -0.328161           -0.292073
# umsent_mean                          -0.387146  -0.328161           -0.292073
# total_cases_stan_start_one            1.000000   0.731918            0.675118
# total_cases_stan_start_start          0.466503   0.101816            0.117125
# total_cases_mean_start_one            1.000000   0.731918            0.675118
# total_cases_mean_start_start          0.466503   0.101816            0.117125
# total_deaths_stan_start_one           0.983161   0.760017            0.698918
# total_deaths_stan_start_start         0.479157   0.113030            0.130460
# VaxFull_stan_start_one                0.955868   0.679553            0.629569
# VaxFull_stan_start_start              0.236191  -0.105311           -0.076512
# VaxFull_mean_start_one                0.955868   0.679553            0.629569
# VaxFull_mean_start_start              0.236191  -0.105311           -0.076512
# cci_stan                              0.094413   0.045618            0.045807
# cci_mean                              0.094413   0.045618            0.045807
# stringency_index_stan_start_one       0.595817   0.700117            0.629771
# stringency_index_stan_start_start    -0.263719   0.125908            0.116354
# stringency_index_mean_start_one       0.595817   0.700117            0.629771
# stringency_index_mean_start_start    -0.263719   0.125908            0.116354
# cci_lag1_stan                         0.098416   0.060226            0.059576
# cci_lag1_mean                         0.098416   0.060226            0.059576
#
#                                    total_deaths  new_deaths  positive_rate  \
# total_cases                            0.983190    0.646423       0.633434
# new_cases                              0.760064    0.857942       0.829708
# new_cases_smoothed                     0.698959    0.748111       0.856726
# total_deaths                           1.000000    0.698337       0.679986
# new_deaths                             0.698337    1.000000       0.780809
# positive_rate                          0.679986    0.780809       1.000000
# stringency_index                       0.699750    0.842179       0.815777
# cci                                    0.104197    0.041404       0.029913
# cci_cur                                0.151590    0.042262       0.036349
# cci_exp                               -0.006539    0.031403       0.011809
# umsent                                -0.326883   -0.262999      -0.293179
# umsent_cur                            -0.390106   -0.316011      -0.347612
# umsent_exp                            -0.262853   -0.210001      -0.237528
# ism_man                                0.289170    0.223233       0.150051
# ism_non                                0.325448    0.200169       0.120814
# cci_lag1                               0.104871    0.048653       0.066128
# cci_lag2                               0.104026    0.082889       0.098298
# cci_lag3                               0.102212    0.102229       0.105567
# cci_lag4                               0.102017    0.099910       0.110448
# cci_lag5                               0.103211    0.103438       0.123641
# cci_lag6                               0.101201    0.117969       0.136888
# cci_lag7                               0.097130    0.115996       0.139058
# cci_lag8                               0.095120    0.111030       0.135428
# total_cases_lag1                       0.977683    0.597031       0.592931
# total_cases_lag2                       0.969486    0.559952       0.585901
# total_deaths_lag1                      0.998647    0.668050       0.660024
# total_deaths_lag2                      0.995180    0.648733       0.651238
# VaxFull                                0.960758    0.584316       0.589924
# umsent_stan                           -0.390106   -0.316011      -0.347612
# umsent_mean                           -0.390106   -0.316011      -0.347612
# total_cases_stan_start_one             0.983190    0.646423       0.633434
# total_cases_stan_start_start           0.343265   -0.125846      -0.136274
# total_cases_mean_start_one             0.983190    0.646423       0.633434
# total_cases_mean_start_start           0.343265   -0.125846      -0.136274
# total_deaths_stan_start_one            0.999960    0.698270       0.679918
# total_deaths_stan_start_start          0.381172   -0.130762      -0.152498
# VaxFull_stan_start_one                 0.960758    0.584316       0.589924
# VaxFull_stan_start_start               0.154874   -0.237148      -0.074681
# VaxFull_mean_start_one                 0.960758    0.584316       0.589924
# VaxFull_mean_start_start               0.154874   -0.237148      -0.074681
# cci_stan                               0.104197    0.041404       0.029913
# cci_mean                               0.104197    0.041404       0.029913
# stringency_index_stan_start_one        0.699750    0.842179       0.815777
# stringency_index_stan_start_start     -0.148649    0.353145       0.285992
# stringency_index_mean_start_one        0.699750    0.842179       0.815777
# stringency_index_mean_start_start     -0.148649    0.353145       0.285992
# cci_lag1_stan                          0.104871    0.048653       0.066128
# cci_lag1_mean                          0.104871    0.048653       0.066128
#
#                                    stringency_index       cci   cci_cur  \
# total_cases                                0.595817  0.094413  0.152775
# new_cases                                  0.700117  0.045618  0.074558
# new_cases_smoothed                         0.629771  0.045807  0.070557
# total_deaths                               0.699750  0.104197  0.151590
# new_deaths                                 0.842179  0.041404  0.042262
# positive_rate                              0.815777  0.029913  0.036349
# stringency_index                           1.000000  0.058560  0.041374
# cci                                        0.058560  1.000000  0.964905
# cci_cur                                    0.041374  0.964905  1.000000
# cci_exp                                    0.079636  0.867310  0.706160
# umsent                                    -0.264573  0.833912  0.740469
# umsent_cur                                -0.327748  0.805629  0.738266
# umsent_exp                                -0.204056  0.808655  0.701386
# ism_man                                    0.241556  0.228768  0.104047
# ism_non                                    0.233188  0.497086  0.399183
# cci_lag1                                   0.064402  0.973085  0.961758
# cci_lag2                                   0.078727  0.945451  0.952111
# cci_lag3                                   0.092404  0.924406  0.941246
# cci_lag4                                   0.102061  0.903368  0.929963
# cci_lag5                                   0.110610  0.885514  0.921167
# cci_lag6                                   0.119004  0.869318  0.911457
# cci_lag7                                   0.125382  0.858597  0.902726
# cci_lag8                                   0.136285  0.841741  0.890179
# total_cases_lag1                           0.571304  0.096609  0.156324
# total_cases_lag2                           0.549348  0.097056  0.158200
# total_deaths_lag1                          0.672832  0.106030  0.156317
# total_deaths_lag2                          0.647972  0.105984  0.159375
# VaxFull                                    0.554323  0.114496  0.172136
# umsent_stan                               -0.327748  0.805629  0.738266
# umsent_mean                               -0.327748  0.805629  0.738266
# total_cases_stan_start_one                 0.595817  0.094413  0.152775
# total_cases_stan_start_start              -0.372268  0.010922  0.084215
# total_cases_mean_start_one                 0.595817  0.094413  0.152775
# total_cases_mean_start_start              -0.372268  0.010922  0.084215
# total_deaths_stan_start_one                0.699661  0.104817  0.152277
# total_deaths_stan_start_start             -0.352017  0.047319  0.116070
# VaxFull_stan_start_one                     0.554323  0.114496  0.172136
# VaxFull_stan_start_start                  -0.270144  0.029051  0.085794
# VaxFull_mean_start_one                     0.554323  0.114496  0.172136
# VaxFull_mean_start_start                  -0.270144  0.029051  0.085794
# cci_stan                                   0.058560  1.000000  0.964905
# cci_mean                                   0.058560  1.000000  0.964905
# stringency_index_stan_start_one            1.000000  0.058560  0.041374
# stringency_index_stan_start_start          0.475828 -0.048911 -0.131259
# stringency_index_mean_start_one            1.000000  0.058560  0.041374
# stringency_index_mean_start_start          0.475828 -0.048911 -0.131259
# cci_lag1_stan                              0.064402  0.973085  0.961758
# cci_lag1_mean                              0.064402  0.973085  0.961758
#
#                                     cci_exp    umsent  umsent_cur  umsent_exp  \
# total_cases                       -0.035227 -0.329655   -0.387146   -0.269706
# new_cases                         -0.018546 -0.279644   -0.328161   -0.228921
# new_cases_smoothed                -0.010404 -0.248900   -0.292073   -0.203722
# total_deaths                      -0.006539 -0.326883   -0.390106   -0.262853
# new_deaths                         0.031403 -0.262999   -0.316011   -0.210001
# positive_rate                      0.011809 -0.293179   -0.347612   -0.237528
# stringency_index                   0.079636 -0.264573   -0.327748   -0.204056
# cci                                0.867310  0.833912    0.805629    0.808655
# cci_cur                            0.706160  0.740469    0.738266    0.701386
# cci_exp                            1.000000  0.844950    0.772888    0.850914
# umsent                             0.844950  1.000000    0.955842    0.977017
# umsent_cur                         0.772888  0.955842    1.000000    0.871245
# umsent_exp                         0.850914  0.977017    0.871245    1.000000
# ism_man                            0.419530  0.155758    0.167617    0.138570
# ism_non                            0.583720  0.395192    0.415763    0.358607
# cci_lag1                           0.800775  0.798701    0.778003    0.769841
# cci_lag2                           0.744593  0.755536    0.744596    0.721924
# cci_lag3                           0.708455  0.723546    0.721372    0.685308
# cci_lag4                           0.673085  0.696706    0.697647    0.657717
# cci_lag5                           0.641569  0.677450    0.677697    0.640042
# cci_lag6                           0.616249  0.659817    0.656426    0.626028
# cci_lag7                           0.603875  0.646682    0.638509    0.617011
# cci_lag8                           0.582208  0.627427    0.613927    0.602661
# total_cases_lag1                  -0.036028 -0.326269   -0.383472   -0.266735
# total_cases_lag2                  -0.038360 -0.323433   -0.381081   -0.263708
# total_deaths_lag1                 -0.010556 -0.325054   -0.388034   -0.261299
# total_deaths_lag2                 -0.016481 -0.324631   -0.387150   -0.261240
# VaxFull                           -0.017708 -0.307878   -0.367628   -0.247355
# umsent_stan                        0.772888  0.955842    1.000000    0.871245
# umsent_mean                        0.772888  0.955842    1.000000    0.871245
# total_cases_stan_start_one        -0.035227 -0.329655   -0.387146   -0.269706
# total_cases_stan_start_start      -0.130514 -0.096601   -0.096564   -0.091321
# total_cases_mean_start_one        -0.035227 -0.329655   -0.387146   -0.269706
# total_cases_mean_start_start      -0.130514 -0.096601   -0.096564   -0.091321
# total_deaths_stan_start_one       -0.006169 -0.326412   -0.389580   -0.262444
# total_deaths_stan_start_start     -0.092760 -0.070508   -0.074580   -0.063612
# VaxFull_stan_start_one            -0.017708 -0.307878   -0.367628   -0.247355
# VaxFull_stan_start_start          -0.084390 -0.097095   -0.099713   -0.089524
# VaxFull_mean_start_one            -0.017708 -0.307878   -0.367628   -0.247355
# VaxFull_mean_start_start          -0.084390 -0.097095   -0.099713   -0.089524
# cci_stan                           0.867310  0.833912    0.805629    0.808655
# cci_mean                           0.867310  0.833912    0.805629    0.808655
# stringency_index_stan_start_one    0.079636 -0.264573   -0.327748   -0.204056
# stringency_index_stan_start_start  0.117317  0.026469    0.009233    0.037488
# stringency_index_mean_start_one    0.079636 -0.264573   -0.327748   -0.204056
# stringency_index_mean_start_start  0.117317  0.026469    0.009233    0.037488
# cci_lag1_stan                      0.800775  0.798701    0.778003    0.769841
# cci_lag1_mean                      0.800775  0.798701    0.778003    0.769841
#
#                                     ism_man   ism_non  cci_lag1  cci_lag2  \
# total_cases                        0.253471  0.280734  0.098416  0.100656
# new_cases                          0.244688  0.237940  0.060226  0.080145
# new_cases_smoothed                 0.229843  0.208248  0.059576  0.072448
# total_deaths                       0.289170  0.325448  0.104871  0.104026
# new_deaths                         0.223233  0.200169  0.048653  0.082889
# positive_rate                      0.150051  0.120814  0.066128  0.098298
# stringency_index                   0.241556  0.233188  0.064402  0.078727
# cci                                0.228768  0.497086  0.973085  0.945451
# cci_cur                            0.104047  0.399183  0.961758  0.952111
# cci_exp                            0.419530  0.583720  0.800775  0.744593
# umsent                             0.155758  0.395192  0.798701  0.755536
# umsent_cur                         0.167617  0.415763  0.778003  0.744596
# umsent_exp                         0.138570  0.358607  0.769841  0.721924
# ism_man                            1.000000  0.775959  0.184363  0.135885
# ism_non                            0.775959  1.000000  0.453185  0.399258
# cci_lag1                           0.184363  0.453185  1.000000  0.973234
# cci_lag2                           0.135885  0.399258  0.973234  1.000000
# cci_lag3                           0.089721  0.359653  0.945534  0.973168
# cci_lag4                           0.046132  0.325300  0.924507  0.945518
# cci_lag5                           0.008798  0.294728  0.903491  0.924539
# cci_lag6                          -0.025994  0.264327  0.885875  0.903661
# cci_lag7                          -0.061811  0.226954  0.869627  0.885961
# cci_lag8                          -0.091424  0.189381  0.858335  0.869260
# total_cases_lag1                   0.246001  0.279917  0.100044  0.100522
# total_cases_lag2                   0.237758  0.275414  0.103089  0.102796
# total_deaths_lag1                  0.285084  0.324702  0.108111  0.105671
# total_deaths_lag2                  0.278418  0.319823  0.110603  0.109491
# VaxFull                            0.255563  0.323756  0.121760  0.122809
# umsent_stan                        0.167617  0.415763  0.778003  0.744596
# umsent_mean                        0.167617  0.415763  0.778003  0.744596
# total_cases_stan_start_one         0.253471  0.280734  0.098416  0.100656
# total_cases_stan_start_start       0.050547  0.063511  0.001415 -0.007221
# total_cases_mean_start_one         0.253471  0.280734  0.098416  0.100656
# total_cases_mean_start_start       0.050547  0.063511  0.001415 -0.007221
# total_deaths_stan_start_one        0.289024  0.325609  0.105446  0.104572
# total_deaths_stan_start_start      0.095560  0.145557  0.027208  0.008834
# VaxFull_stan_start_one             0.255563  0.323756  0.121760  0.122809
# VaxFull_stan_start_start          -0.110682 -0.022235  0.052474  0.058441
# VaxFull_mean_start_one             0.255563  0.323756  0.121760  0.122809
# VaxFull_mean_start_start          -0.110682 -0.022235  0.052474  0.058441
# cci_stan                           0.228768  0.497086  0.973085  0.945451
# cci_mean                           0.228768  0.497086  0.973085  0.945451
# stringency_index_stan_start_one    0.241556  0.233188  0.064402  0.078727
# stringency_index_stan_start_start  0.058994  0.006946 -0.067118 -0.049989
# stringency_index_mean_start_one    0.241556  0.233188  0.064402  0.078727
# stringency_index_mean_start_start  0.058994  0.006946 -0.067118 -0.049989
# cci_lag1_stan                      0.184363  0.453185  1.000000  0.973234
# cci_lag1_mean                      0.184363  0.453185  1.000000  0.973234
#
#                                    cci_lag3  cci_lag4  cci_lag5  cci_lag6  \
# total_cases                        0.099427  0.098822  0.099753  0.098045
# new_cases                          0.084317  0.081383  0.089600  0.103990
# new_cases_smoothed                 0.073124  0.070697  0.077625  0.093451
# total_deaths                       0.102212  0.102017  0.103211  0.101201
# new_deaths                         0.102229  0.099910  0.103438  0.117969
# positive_rate                      0.105567  0.110448  0.123641  0.136888
# stringency_index                   0.092404  0.102061  0.110610  0.119004
# cci                                0.924406  0.903368  0.885514  0.869318
# cci_cur                            0.941246  0.929963  0.921167  0.911457
# cci_exp                            0.708455  0.673085  0.641569  0.616249
# umsent                             0.723546  0.696706  0.677450  0.659817
# umsent_cur                         0.721372  0.697647  0.677697  0.656426
# umsent_exp                         0.685308  0.657717  0.640042  0.626028
# ism_man                            0.089721  0.046132  0.008798 -0.025994
# ism_non                            0.359653  0.325300  0.294728  0.264327
# cci_lag1                           0.945534  0.924507  0.903491  0.885875
# cci_lag2                           0.973168  0.945518  0.924539  0.903661
# cci_lag3                           1.000000  0.973208  0.945618  0.924643
# cci_lag4                           0.973208  1.000000  0.973256  0.945711
# cci_lag5                           0.945618  0.973256  1.000000  0.973355
# cci_lag6                           0.924643  0.945711  0.973355  1.000000
# cci_lag7                           0.903765  0.924771  0.945895  0.973359
# cci_lag8                           0.885863  0.903680  0.924711  0.945736
# total_cases_lag1                   0.098896  0.098438  0.099387  0.095964
# total_cases_lag2                   0.099065  0.098209  0.099390  0.095783
# total_deaths_lag1                  0.101533  0.100341  0.101459  0.099052
# total_deaths_lag2                  0.103477  0.099851  0.099980  0.097314
# VaxFull                            0.117763  0.111806  0.107166  0.099750
# umsent_stan                        0.721372  0.697647  0.677697  0.656426
# umsent_mean                        0.721372  0.697647  0.677697  0.656426
# total_cases_stan_start_one         0.099427  0.098822  0.099753  0.098045
# total_cases_stan_start_start      -0.018140 -0.028248 -0.037113 -0.051448
# total_cases_mean_start_one         0.099427  0.098822  0.099753  0.098045
# total_cases_mean_start_start      -0.018140 -0.028248 -0.037113 -0.051448
# total_deaths_stan_start_one        0.102745  0.102552  0.103892  0.101911
# total_deaths_stan_start_start     -0.007137 -0.019878 -0.030800 -0.044210
# VaxFull_stan_start_one             0.117763  0.111806  0.107166  0.099750
# VaxFull_stan_start_start           0.055680  0.064914  0.069855  0.067276
# VaxFull_mean_start_one             0.117763  0.111806  0.107166  0.099750
# VaxFull_mean_start_start           0.055680  0.064914  0.069855  0.067276
# cci_stan                           0.924406  0.903368  0.885514  0.869318
# cci_mean                           0.924406  0.903368  0.885514  0.869318
# stringency_index_stan_start_one    0.092404  0.102061  0.110610  0.119004
# stringency_index_stan_start_start -0.027775 -0.018005 -0.012956 -0.002853
# stringency_index_mean_start_one    0.092404  0.102061  0.110610  0.119004
# stringency_index_mean_start_start -0.027775 -0.018005 -0.012956 -0.002853
# cci_lag1_stan                      0.945534  0.924507  0.903491  0.885875
# cci_lag1_mean                      0.945534  0.924507  0.903491  0.885875
#
#                                    cci_lag7  cci_lag8  total_cases_lag1  \
# total_cases                        0.094816  0.093872          0.995610
# new_cases                          0.098536  0.085311          0.678265
# new_cases_smoothed                 0.098789  0.087233          0.613095
# total_deaths                       0.097130  0.095120          0.977683
# new_deaths                         0.115996  0.111030          0.597031
# positive_rate                      0.139058  0.135428          0.592931
# stringency_index                   0.125382  0.136285          0.571304
# cci                                0.858597  0.841741          0.096609
# cci_cur                            0.902726  0.890179          0.156324
# cci_exp                            0.603875  0.582208         -0.036028
# umsent                             0.646682  0.627427         -0.326269
# umsent_cur                         0.638509  0.613927         -0.383472
# umsent_exp                         0.617011  0.602661         -0.266735
# ism_man                           -0.061811 -0.091424          0.246001
# ism_non                            0.226954  0.189381          0.279917
# cci_lag1                           0.869627  0.858335          0.100044
# cci_lag2                           0.885961  0.869260          0.100522
# cci_lag3                           0.903765  0.885863          0.098896
# cci_lag4                           0.924771  0.903680          0.098438
# cci_lag5                           0.945895  0.924711          0.099387
# cci_lag6                           0.973359  0.945736          0.095964
# cci_lag7                           1.000000  0.973330          0.090923
# cci_lag8                           0.973330  1.000000          0.090331
# total_cases_lag1                   0.090923  0.090331          1.000000
# total_cases_lag2                   0.088707  0.086253          0.995025
# total_deaths_lag1                  0.094325  0.092467          0.982974
# total_deaths_lag2                  0.092012  0.089549          0.984859
# VaxFull                            0.089641  0.080310          0.957171
# umsent_stan                        0.638509  0.613927         -0.383472
# umsent_mean                        0.638509  0.613927         -0.383472
# total_cases_stan_start_one         0.094816  0.093872          0.995610
# total_cases_stan_start_start      -0.067198 -0.075350          0.481349
# total_cases_mean_start_one         0.094816  0.093872          0.995610
# total_cases_mean_start_start      -0.067198 -0.075350          0.481349
# total_deaths_stan_start_one        0.097626  0.095746          0.977656
# total_deaths_stan_start_start     -0.064570 -0.084762          0.496750
# VaxFull_stan_start_one             0.089641  0.080310          0.957171
# VaxFull_stan_start_start           0.074652  0.080531          0.263514
# VaxFull_mean_start_one             0.089641  0.080310          0.957171
# VaxFull_mean_start_start           0.074652  0.080531          0.263514
# cci_stan                           0.858597  0.841741          0.096609
# cci_mean                           0.858597  0.841741          0.096609
# stringency_index_stan_start_one    0.125382  0.136285          0.571304
# stringency_index_stan_start_start -0.005081  0.001340         -0.295727
# stringency_index_mean_start_one    0.125382  0.136285          0.571304
# stringency_index_mean_start_start -0.005081  0.001340         -0.295727
# cci_lag1_stan                      0.869627  0.858335          0.100044
# cci_lag1_mean                      0.869627  0.858335          0.100044
#
#                                    total_cases_lag2  total_deaths_lag1  \
# total_cases                                0.987893           0.985699
# new_cases                                  0.667050           0.742266
# new_cases_smoothed                         0.597711           0.680348
# total_deaths                               0.969486           0.998647
# new_deaths                                 0.559952           0.668050
# positive_rate                              0.585901           0.660024
# stringency_index                           0.549348           0.672832
# cci                                        0.097056           0.106030
# cci_cur                                    0.158200           0.156317
# cci_exp                                   -0.038360          -0.010556
# umsent                                    -0.323433          -0.325054
# umsent_cur                                -0.381081          -0.388034
# umsent_exp                                -0.263708          -0.261299
# ism_man                                    0.237758           0.285084
# ism_non                                    0.275414           0.324702
# cci_lag1                                   0.103089           0.108111
# cci_lag2                                   0.102796           0.105671
# cci_lag3                                   0.099065           0.101533
# cci_lag4                                   0.098209           0.100341
# cci_lag5                                   0.099390           0.101459
# cci_lag6                                   0.095783           0.099052
# cci_lag7                                   0.088707           0.094325
# cci_lag8                                   0.086253           0.092467
# total_cases_lag1                           0.995025           0.982974
# total_cases_lag2                           1.000000           0.977825
# total_deaths_lag1                          0.977825           1.000000
# total_deaths_lag2                          0.982618           0.998613
# VaxFull                                    0.958933           0.969030
# umsent_stan                               -0.381081          -0.388034
# umsent_mean                               -0.381081          -0.388034
# total_cases_stan_start_one                 0.987893           0.985699
# total_cases_stan_start_start               0.490517           0.370119
# total_cases_mean_start_one                 0.987893           0.985699
# total_cases_mean_start_start               0.490517           0.370119
# total_deaths_stan_start_one                0.969461           0.998610
# total_deaths_stan_start_start              0.508451           0.408763
# VaxFull_stan_start_one                     0.958933           0.969030
# VaxFull_stan_start_start                   0.292440           0.188215
# VaxFull_mean_start_one                     0.958933           0.969030
# VaxFull_mean_start_start                   0.292440           0.188215
# cci_stan                                   0.097056           0.106030
# cci_mean                                   0.097056           0.106030
# stringency_index_stan_start_one            0.549348           0.672832
# stringency_index_stan_start_start         -0.321393          -0.183863
# stringency_index_mean_start_one            0.549348           0.672832
# stringency_index_mean_start_start         -0.321393          -0.183863
# cci_lag1_stan                              0.103089           0.108111
# cci_lag1_mean                              0.103089           0.108111
#
#                                    total_deaths_lag2   VaxFull  umsent_stan  \
# total_cases                                 0.986382  0.955868    -0.387146
# new_cases                                   0.736626  0.679553    -0.328161
# new_cases_smoothed                          0.673357  0.629569    -0.292073
# total_deaths                                0.995180  0.960758    -0.390106
# new_deaths                                  0.648733  0.584316    -0.316011
# positive_rate                               0.651238  0.589924    -0.347612
# stringency_index                            0.647972  0.554323    -0.327748
# cci                                         0.105984  0.114496     0.805629
# cci_cur                                     0.159375  0.172136     0.738266
# cci_exp                                    -0.016481 -0.017708     0.772888
# umsent                                     -0.324631 -0.307878     0.955842
# umsent_cur                                 -0.387150 -0.367628     1.000000
# umsent_exp                                 -0.261240 -0.247355     0.871245
# ism_man                                     0.278418  0.255563     0.167617
# ism_non                                     0.319823  0.323756     0.415763
# cci_lag1                                    0.110603  0.121760     0.778003
# cci_lag2                                    0.109491  0.122809     0.744596
# cci_lag3                                    0.103477  0.117763     0.721372
# cci_lag4                                    0.099851  0.111806     0.697647
# cci_lag5                                    0.099980  0.107166     0.677697
# cci_lag6                                    0.097314  0.099750     0.656426
# cci_lag7                                    0.092012  0.089641     0.638509
# cci_lag8                                    0.089549  0.080310     0.613927
# total_cases_lag1                            0.984859  0.957171    -0.383472
# total_cases_lag2                            0.982618  0.958933    -0.381081
# total_deaths_lag1                           0.998613  0.969030    -0.388034
# total_deaths_lag2                           1.000000  0.976092    -0.387150
# VaxFull                                     0.976092  1.000000    -0.367628
# umsent_stan                                -0.387150 -0.367628     1.000000
# umsent_mean                                -0.387150 -0.367628     1.000000
# total_cases_stan_start_one                  0.986382  0.955868    -0.387146
# total_cases_stan_start_start                0.393748  0.452593    -0.096564
# total_cases_mean_start_one                  0.986382  0.955868    -0.387146
# total_cases_mean_start_start                0.393748  0.452593    -0.096564
# total_deaths_stan_start_one                 0.995146  0.960733    -0.389580
# total_deaths_stan_start_start               0.431849  0.503718    -0.074580
# VaxFull_stan_start_one                      0.976092  1.000000    -0.367628
# VaxFull_stan_start_start                    0.219018  0.354034    -0.099713
# VaxFull_mean_start_one                      0.976092  1.000000    -0.367628
# VaxFull_mean_start_start                    0.219018  0.354034    -0.099713
# cci_stan                                    0.105984  0.114496     0.805629
# cci_mean                                    0.105984  0.114496     0.805629
# stringency_index_stan_start_one             0.647972  0.554323    -0.327748
# stringency_index_stan_start_start          -0.213711 -0.286487     0.009233
# stringency_index_mean_start_one             0.647972  0.554323    -0.327748
# stringency_index_mean_start_start          -0.213711 -0.286487     0.009233
# cci_lag1_stan                               0.110603  0.121760     0.778003
# cci_lag1_mean                               0.110603  0.121760     0.778003
#
#                                    umsent_mean  total_cases_stan_start_one  \
# total_cases                          -0.387146                    1.000000
# new_cases                            -0.328161                    0.731918
# new_cases_smoothed                   -0.292073                    0.675118
# total_deaths                         -0.390106                    0.983190
# new_deaths                           -0.316011                    0.646423
# positive_rate                        -0.347612                    0.633434
# stringency_index                     -0.327748                    0.595817
# cci                                   0.805629                    0.094413
# cci_cur                               0.738266                    0.152775
# cci_exp                               0.772888                   -0.035227
# umsent                                0.955842                   -0.329655
# umsent_cur                            1.000000                   -0.387146
# umsent_exp                            0.871245                   -0.269706
# ism_man                               0.167617                    0.253471
# ism_non                               0.415763                    0.280734
# cci_lag1                              0.778003                    0.098416
# cci_lag2                              0.744596                    0.100656
# cci_lag3                              0.721372                    0.099427
# cci_lag4                              0.697647                    0.098822
# cci_lag5                              0.677697                    0.099753
# cci_lag6                              0.656426                    0.098045
# cci_lag7                              0.638509                    0.094816
# cci_lag8                              0.613927                    0.093872
# total_cases_lag1                     -0.383472                    0.995610
# total_cases_lag2                     -0.381081                    0.987893
# total_deaths_lag1                    -0.388034                    0.985699
# total_deaths_lag2                    -0.387150                    0.986382
# VaxFull                              -0.367628                    0.955868
# umsent_stan                           1.000000                   -0.387146
# umsent_mean                           1.000000                   -0.387146
# total_cases_stan_start_one           -0.387146                    1.000000
# total_cases_stan_start_start         -0.096564                    0.466503
# total_cases_mean_start_one           -0.387146                    1.000000
# total_cases_mean_start_start         -0.096564                    0.466503
# total_deaths_stan_start_one          -0.389580                    0.983161
# total_deaths_stan_start_start        -0.074580                    0.479157
# VaxFull_stan_start_one               -0.367628                    0.955868
# VaxFull_stan_start_start             -0.099713                    0.236191
# VaxFull_mean_start_one               -0.367628                    0.955868
# VaxFull_mean_start_start             -0.099713                    0.236191
# cci_stan                              0.805629                    0.094413
# cci_mean                              0.805629                    0.094413
# stringency_index_stan_start_one      -0.327748                    0.595817
# stringency_index_stan_start_start     0.009233                   -0.263719
# stringency_index_mean_start_one      -0.327748                    0.595817
# stringency_index_mean_start_start     0.009233                   -0.263719
# cci_lag1_stan                         0.778003                    0.098416
# cci_lag1_mean                         0.778003                    0.098416
#
#                                    total_cases_stan_start_start  \
# total_cases                                            0.466503
# new_cases                                              0.101816
# new_cases_smoothed                                     0.117125
# total_deaths                                           0.343265
# new_deaths                                            -0.125846
# positive_rate                                         -0.136274
# stringency_index                                      -0.372268
# cci                                                    0.010922
# cci_cur                                                0.084215
# cci_exp                                               -0.130514
# umsent                                                -0.096601
# umsent_cur                                            -0.096564
# umsent_exp                                            -0.091321
# ism_man                                                0.050547
# ism_non                                                0.063511
# cci_lag1                                               0.001415
# cci_lag2                                              -0.007221
# cci_lag3                                              -0.018140
# cci_lag4                                              -0.028248
# cci_lag5                                              -0.037113
# cci_lag6                                              -0.051448
# cci_lag7                                              -0.067198
# cci_lag8                                              -0.075350
# total_cases_lag1                                       0.481349
# total_cases_lag2                                       0.490517
# total_deaths_lag1                                      0.370119
# total_deaths_lag2                                      0.393748
# VaxFull                                                0.452593
# umsent_stan                                           -0.096564
# umsent_mean                                           -0.096564
# total_cases_stan_start_one                             0.466503
# total_cases_stan_start_start                           1.000000
# total_cases_mean_start_one                             0.466503
# total_cases_mean_start_start                           1.000000
# total_deaths_stan_start_one                            0.343340
# total_deaths_stan_start_start                          0.943789
# VaxFull_stan_start_one                                 0.452593
# VaxFull_stan_start_start                               0.468757
# VaxFull_mean_start_one                                 0.452593
# VaxFull_mean_start_start                               0.468757
# cci_stan                                               0.010922
# cci_mean                                               0.010922
# stringency_index_stan_start_one                       -0.372268
# stringency_index_stan_start_start                     -0.623910
# stringency_index_mean_start_one                       -0.372268
# stringency_index_mean_start_start                     -0.623910
# cci_lag1_stan                                          0.001415
# cci_lag1_mean                                          0.001415
#
#                                    total_cases_mean_start_one  \
# total_cases                                          1.000000
# new_cases                                            0.731918
# new_cases_smoothed                                   0.675118
# total_deaths                                         0.983190
# new_deaths                                           0.646423
# positive_rate                                        0.633434
# stringency_index                                     0.595817
# cci                                                  0.094413
# cci_cur                                              0.152775
# cci_exp                                             -0.035227
# umsent                                              -0.329655
# umsent_cur                                          -0.387146
# umsent_exp                                          -0.269706
# ism_man                                              0.253471
# ism_non                                              0.280734
# cci_lag1                                             0.098416
# cci_lag2                                             0.100656
# cci_lag3                                             0.099427
# cci_lag4                                             0.098822
# cci_lag5                                             0.099753
# cci_lag6                                             0.098045
# cci_lag7                                             0.094816
# cci_lag8                                             0.093872
# total_cases_lag1                                     0.995610
# total_cases_lag2                                     0.987893
# total_deaths_lag1                                    0.985699
# total_deaths_lag2                                    0.986382
# VaxFull                                              0.955868
# umsent_stan                                         -0.387146
# umsent_mean                                         -0.387146
# total_cases_stan_start_one                           1.000000
# total_cases_stan_start_start                         0.466503
# total_cases_mean_start_one                           1.000000
# total_cases_mean_start_start                         0.466503
# total_deaths_stan_start_one                          0.983161
# total_deaths_stan_start_start                        0.479157
# VaxFull_stan_start_one                               0.955868
# VaxFull_stan_start_start                             0.236191
# VaxFull_mean_start_one                               0.955868
# VaxFull_mean_start_start                             0.236191
# cci_stan                                             0.094413
# cci_mean                                             0.094413
# stringency_index_stan_start_one                      0.595817
# stringency_index_stan_start_start                   -0.263719
# stringency_index_mean_start_one                      0.595817
# stringency_index_mean_start_start                   -0.263719
# cci_lag1_stan                                        0.098416
# cci_lag1_mean                                        0.098416
#
#                                    total_cases_mean_start_start  \
# total_cases                                            0.466503
# new_cases                                              0.101816
# new_cases_smoothed                                     0.117125
# total_deaths                                           0.343265
# new_deaths                                            -0.125846
# positive_rate                                         -0.136274
# stringency_index                                      -0.372268
# cci                                                    0.010922
# cci_cur                                                0.084215
# cci_exp                                               -0.130514
# umsent                                                -0.096601
# umsent_cur                                            -0.096564
# umsent_exp                                            -0.091321
# ism_man                                                0.050547
# ism_non                                                0.063511
# cci_lag1                                               0.001415
# cci_lag2                                              -0.007221
# cci_lag3                                              -0.018140
# cci_lag4                                              -0.028248
# cci_lag5                                              -0.037113
# cci_lag6                                              -0.051448
# cci_lag7                                              -0.067198
# cci_lag8                                              -0.075350
# total_cases_lag1                                       0.481349
# total_cases_lag2                                       0.490517
# total_deaths_lag1                                      0.370119
# total_deaths_lag2                                      0.393748
# VaxFull                                                0.452593
# umsent_stan                                           -0.096564
# umsent_mean                                           -0.096564
# total_cases_stan_start_one                             0.466503
# total_cases_stan_start_start                           1.000000
# total_cases_mean_start_one                             0.466503
# total_cases_mean_start_start                           1.000000
# total_deaths_stan_start_one                            0.343340
# total_deaths_stan_start_start                          0.943789
# VaxFull_stan_start_one                                 0.452593
# VaxFull_stan_start_start                               0.468757
# VaxFull_mean_start_one                                 0.452593
# VaxFull_mean_start_start                               0.468757
# cci_stan                                               0.010922
# cci_mean                                               0.010922
# stringency_index_stan_start_one                       -0.372268
# stringency_index_stan_start_start                     -0.623910
# stringency_index_mean_start_one                       -0.372268
# stringency_index_mean_start_start                     -0.623910
# cci_lag1_stan                                          0.001415
# cci_lag1_mean                                          0.001415
#
#                                    total_deaths_stan_start_one  \
# total_cases                                           0.983161
# new_cases                                             0.760017
# ...
# cci_lag6                           0.869318                         0.119004
# cci_lag7                           0.858597                         0.125382
# cci_lag8                           0.841741                         0.136285
# total_cases_lag1                   0.096609                         0.571304
# total_cases_lag2                   0.097056                         0.549348
# total_deaths_lag1                  0.106030                         0.672832
# total_deaths_lag2                  0.105984                         0.647972
# VaxFull                            0.114496                         0.554323
# umsent_stan                        0.805629                        -0.327748
# umsent_mean                        0.805629                        -0.327748
# total_cases_stan_start_one         0.094413                         0.595817
# total_cases_stan_start_start       0.010922                        -0.372268
# total_cases_mean_start_one         0.094413                         0.595817
# total_cases_mean_start_start       0.010922                        -0.372268
# total_deaths_stan_start_one        0.104817                         0.699661
# total_deaths_stan_start_start      0.047319                        -0.352017
# VaxFull_stan_start_one             0.114496                         0.554323
# VaxFull_stan_start_start           0.029051                        -0.270144
# VaxFull_mean_start_one             0.114496                         0.554323
# VaxFull_mean_start_start           0.029051                        -0.270144
# cci_stan                           1.000000                         0.058560
# cci_mean                           1.000000                         0.058560
# stringency_index_stan_start_one    0.058560                         1.000000
# stringency_index_stan_start_start -0.048911                         0.475828
# stringency_index_mean_start_one    0.058560                         1.000000
# stringency_index_mean_start_start -0.048911                         0.475828
# cci_lag1_stan                      0.973085                         0.064402
# cci_lag1_mean                      0.973085                         0.064402
#
#                                    stringency_index_stan_start_start  \
# total_cases                                                -0.263719
# new_cases                                                   0.125908
# new_cases_smoothed                                          0.116354
# total_deaths                                               -0.148649
# new_deaths                                                  0.353145
# positive_rate                                               0.285992
# stringency_index                                            0.475828
# cci                                                        -0.048911
# cci_cur                                                    -0.131259
# cci_exp                                                     0.117317
# umsent                                                      0.026469
# umsent_cur                                                  0.009233
# umsent_exp                                                  0.037488
# ism_man                                                     0.058994
# ism_non                                                     0.006946
# cci_lag1                                                   -0.067118
# cci_lag2                                                   -0.049989
# cci_lag3                                                   -0.027775
# cci_lag4                                                   -0.018005
# cci_lag5                                                   -0.012956
# cci_lag6                                                   -0.002853
# cci_lag7                                                   -0.005081
# cci_lag8                                                    0.001340
# total_cases_lag1                                           -0.295727
# total_cases_lag2                                           -0.321393
# total_deaths_lag1                                          -0.183863
# total_deaths_lag2                                          -0.213711
# VaxFull                                                    -0.286487
# umsent_stan                                                 0.009233
# umsent_mean                                                 0.009233
# total_cases_stan_start_one                                 -0.263719
# total_cases_stan_start_start                               -0.623910
# total_cases_mean_start_one                                 -0.263719
# total_cases_mean_start_start                               -0.623910
# total_deaths_stan_start_one                                -0.148695
# total_deaths_stan_start_start                              -0.577004
# VaxFull_stan_start_one                                     -0.286487
# VaxFull_stan_start_start                                   -0.590889
# VaxFull_mean_start_one                                     -0.286487
# VaxFull_mean_start_start                                   -0.590889
# cci_stan                                                   -0.048911
# cci_mean                                                   -0.048911
# stringency_index_stan_start_one                             0.475828
# stringency_index_stan_start_start                           1.000000
# stringency_index_mean_start_one                             0.475828
# stringency_index_mean_start_start                           1.000000
# cci_lag1_stan                                              -0.067118
# cci_lag1_mean                                              -0.067118
#
#                                    stringency_index_mean_start_one  \
# total_cases                                               0.595817
# new_cases                                                 0.700117
# new_cases_smoothed                                        0.629771
# total_deaths                                              0.699750
# new_deaths                                                0.842179
# positive_rate                                             0.815777
# stringency_index                                          1.000000
# cci                                                       0.058560
# cci_cur                                                   0.041374
# cci_exp                                                   0.079636
# umsent                                                   -0.264573
# umsent_cur                                               -0.327748
# umsent_exp                                               -0.204056
# ism_man                                                   0.241556
# ism_non                                                   0.233188
# cci_lag1                                                  0.064402
# cci_lag2                                                  0.078727
# cci_lag3                                                  0.092404
# cci_lag4                                                  0.102061
# cci_lag5                                                  0.110610
# cci_lag6                                                  0.119004
# cci_lag7                                                  0.125382
# cci_lag8                                                  0.136285
# total_cases_lag1                                          0.571304
# total_cases_lag2                                          0.549348
# total_deaths_lag1                                         0.672832
# total_deaths_lag2                                         0.647972
# VaxFull                                                   0.554323
# umsent_stan                                              -0.327748
# umsent_mean                                              -0.327748
# total_cases_stan_start_one                                0.595817
# total_cases_stan_start_start                             -0.372268
# total_cases_mean_start_one                                0.595817
# total_cases_mean_start_start                             -0.372268
# total_deaths_stan_start_one                               0.699661
# total_deaths_stan_start_start                            -0.352017
# VaxFull_stan_start_one                                    0.554323
# VaxFull_stan_start_start                                 -0.270144
# VaxFull_mean_start_one                                    0.554323
# VaxFull_mean_start_start                                 -0.270144
# cci_stan                                                  0.058560
# cci_mean                                                  0.058560
# stringency_index_stan_start_one                           1.000000
# stringency_index_stan_start_start                         0.475828
# stringency_index_mean_start_one                           1.000000
# stringency_index_mean_start_start                         0.475828
# cci_lag1_stan                                             0.064402
# cci_lag1_mean                                             0.064402
#
#                                    stringency_index_mean_start_start  \
# total_cases                                                -0.263719
# new_cases                                                   0.125908
# new_cases_smoothed                                          0.116354
# total_deaths                                               -0.148649
# new_deaths                                                  0.353145
# positive_rate                                               0.285992
# stringency_index                                            0.475828
# cci                                                        -0.048911
# cci_cur                                                    -0.131259
# cci_exp                                                     0.117317
# umsent                                                      0.026469
# umsent_cur                                                  0.009233
# umsent_exp                                                  0.037488
# ism_man                                                     0.058994
# ism_non                                                     0.006946
# cci_lag1                                                   -0.067118
# cci_lag2                                                   -0.049989
# cci_lag3                                                   -0.027775
# cci_lag4                                                   -0.018005
# cci_lag5                                                   -0.012956
# cci_lag6                                                   -0.002853
# cci_lag7                                                   -0.005081
# cci_lag8                                                    0.001340
# total_cases_lag1                                           -0.295727
# total_cases_lag2                                           -0.321393
# total_deaths_lag1                                          -0.183863
# total_deaths_lag2                                          -0.213711
# VaxFull                                                    -0.286487
# umsent_stan                                                 0.009233
# umsent_mean                                                 0.009233
# total_cases_stan_start_one                                 -0.263719
# total_cases_stan_start_start                               -0.623910
# total_cases_mean_start_one                                 -0.263719
# total_cases_mean_start_start                               -0.623910
# total_deaths_stan_start_one                                -0.148695
# total_deaths_stan_start_start                              -0.577004
# VaxFull_stan_start_one                                     -0.286487
# VaxFull_stan_start_start                                   -0.590889
# VaxFull_mean_start_one                                     -0.286487
# VaxFull_mean_start_start                                   -0.590889
# cci_stan                                                   -0.048911
# cci_mean                                                   -0.048911
# stringency_index_stan_start_one                             0.475828
# stringency_index_stan_start_start                           1.000000
# stringency_index_mean_start_one                             0.475828
# stringency_index_mean_start_start                           1.000000
# cci_lag1_stan                                              -0.067118
# cci_lag1_mean                                              -0.067118
#
#                                    cci_lag1_stan  cci_lag1_mean
# total_cases                             0.098416       0.098416
# new_cases                               0.060226       0.060226
# new_cases_smoothed                      0.059576       0.059576
# total_deaths                            0.104871       0.104871
# new_deaths                              0.048653       0.048653
# positive_rate                           0.066128       0.066128
# stringency_index                        0.064402       0.064402
# cci                                     0.973085       0.973085
# cci_cur                                 0.961758       0.961758
# cci_exp                                 0.800775       0.800775
# umsent                                  0.798701       0.798701
# umsent_cur                              0.778003       0.778003
# umsent_exp                              0.769841       0.769841
# ism_man                                 0.184363       0.184363
# ism_non                                 0.453185       0.453185
# cci_lag1                                1.000000       1.000000
# cci_lag2                                0.973234       0.973234
# cci_lag3                                0.945534       0.945534
# cci_lag4                                0.924507       0.924507
# cci_lag5                                0.903491       0.903491
# cci_lag6                                0.885875       0.885875
# cci_lag7                                0.869627       0.869627
# cci_lag8                                0.858335       0.858335
# total_cases_lag1                        0.100044       0.100044
# total_cases_lag2                        0.103089       0.103089
# total_deaths_lag1                       0.108111       0.108111
# total_deaths_lag2                       0.110603       0.110603
# VaxFull                                 0.121760       0.121760
# umsent_stan                             0.778003       0.778003
# umsent_mean                             0.778003       0.778003
# total_cases_stan_start_one              0.098416       0.098416
# total_cases_stan_start_start            0.001415       0.001415
# total_cases_mean_start_one              0.098416       0.098416
# total_cases_mean_start_start            0.001415       0.001415
# total_deaths_stan_start_one             0.105446       0.105446
# total_deaths_stan_start_start           0.027208       0.027208
# VaxFull_stan_start_one                  0.121760       0.121760
# VaxFull_stan_start_start                0.052474       0.052474
# VaxFull_mean_start_one                  0.121760       0.121760
# VaxFull_mean_start_start                0.052474       0.052474
# cci_stan                                0.973085       0.973085
# cci_mean                                0.973085       0.973085
# stringency_index_stan_start_one         0.064402       0.064402
# stringency_index_stan_start_start      -0.067118      -0.067118
# stringency_index_mean_start_one         0.064402       0.064402
# stringency_index_mean_start_start      -0.067118      -0.067118
# cci_lag1_stan                           1.000000       1.000000
# cci_lag1_mean                           1.000000       1.000000

# %% [markdown]
# test for heteroskedasticity

# %%
# can determine order of AR model 

fig, ax = plt.subplots(figsize=(6,3.25))
# if > 0.5 or < -0.5 = high correlation
plt.axhline(y=0.5, color='red')
plot_acf(df['cci'], lags=25, ax=ax)
pacf = plot_pacf(df['cci'], lags=25)

# %%
# Testing lags to  R-squared, p-value
x_columnsar = [ 'cci_lag1', 'cci_lag7', 'cci_lag8']
yar = df['cci']
xar = df[x_columnsar] 
xar = sm.add_constant(xar)
summaryar = sm.OLS(yar,xar).fit()
print(summaryar.summary2())
# look at pacf plot and
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.947
# Dependent Variable: cci              AIC:                1962.8065
# Date:               2022-11-10 17:42 BIC:                1977.6216
# No. Observations:   300              Log-Likelihood:     -977.40
# Df Model:           3                F-statistic:        1799.
# Df Residuals:       296              Prob (F-statistic): 1.23e-189
# R-squared:          0.948            Scale:              40.108
# --------------------------------------------------------------------
#              Coef.    Std.Err.      t      P>|t|     [0.025   0.975]
# --------------------------------------------------------------------
# const        2.2986     1.3914    1.6520   0.0996   -0.4397   5.0369
# cci_lag1     0.9315     0.0269   34.5861   0.0000    0.8785   0.9845
# cci_lag7     0.1395     0.0600    2.3259   0.0207    0.0215   0.2575
# cci_lag8    -0.0957     0.0577   -1.6578   0.0984   -0.2092   0.0179
# ------------------------------------------------------------------
# Omnibus:               36.137       Durbin-Watson:          1.877
# Prob(Omnibus):         0.000        Jarque-Bera (JB):       96.395
# Skew:                  -0.542       Prob(JB):               0.000
# Kurtosis:              5.556        Condition No.:          670
# ==================================================================

# %%
import seaborn as sns
sns.histplot(mo.resid);

# %%
mu, std = stats.norm.fit(mo.resid)
mu, std
# Out:
# (3.51837077990543e-14, 5.114392700741859)

# %%
fig, ax = plt.subplots()
# plot the residuals
sns.histplot(x=mo.resid, ax=ax, stat="density", linewidth=0, kde=True)
ax.set(title="Distribution of residuals", xlabel="residual")

# plot corresponding normal curve
xmin, xmax = plt.xlim() # the maximum x values from the histogram above
x = np.linspace(xmin, xmax, 100) # generate some x values
p = stats.norm.pdf(x, mu, std) # calculate the y values for the normal curve
sns.lineplot(x=x, y=p, color="orange", ax=ax)
plt.show()

# %% [markdown]
# Extras:

# %%
# correlation of model 
round(x.corr(),3)
# Out:
#              const  total_cases  cci_lag5  umsent
# const          NaN          NaN       NaN     NaN
# total_cases    NaN         1.00     0.100  -0.330
# cci_lag5       NaN         0.10     1.000   0.677
# umsent         NaN        -0.33     0.677   1.000

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Centering means and trying to fix multicollinearity

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [date, total_cases, new_cases, new_cases_smoothed, total_deaths, new_deaths, positive_rate, stringency_index, cci, cci_cur, cci_exp, umsent, umsent_cur, umsent_exp, ism_man, ism_non, cci_lag1, cci_lag2, cci_lag3, cci_lag4, cci_lag5, cci_lag6, cci_lag7, cci_lag8, total_cases_lag1, total_cases_lag2, total_deaths_lag1, total_deaths_lag2, VaxFull, umsent_stan, umsent_mean-diff, total_cases_stan-start-one, total_cases_stan-start-start, total_cases_mean-start-one, total_cases_mean-start-start, total_deaths_stan-start-one, total_deaths_stan-start-start, VaxFull_stan-start-one, VaxFull_stan-start-start, VaxFull_mean-start-one, VaxFull_mean-start-start, cci_stan, cci_mean, stringency_index_stan-start-one, stringency_index_stan-start-start, stringency_index_mean-start-one, stringency_index_mean-start-start]
# Index: []

# %%
### Original
#  x_columns = [ 'total_cases', 'stringency_index', 'umsent', 'VaxFull', 'cci_lag1']
#  y = df['cci']

x_columns = [ 'total_cases_stan_start_start', 'stringency_index_stan_start_start', 'umsent_stan', 'cci_lag1_stan']
y = df['cci']
x = df[x_columns] 
x = sm.add_constant(x)
summary = sm.OLS(y,x).fit()#cov_type='HC3')
print(summary.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cci   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     1535.
# Date:                Sat, 12 Nov 2022   Prob (F-statistic):          4.76e-196
# Time:                        20:49:06   Log-Likelihood:                -958.49
# No. Observations:                 300   AIC:                             1927.
# Df Residuals:                     295   BIC:                             1945.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                95.4974      0.347    275.578      0.000      94.815      96.179
# total_cases_stan_start_start          4.6600      1.665      2.798      0.005       1.382       7.938
# stringency_index_stan_start_start     6.0637      2.641      2.296      0.022       0.867      11.261
# umsent_stan                           3.3238      0.520      6.396      0.000       2.301       4.347
# cci_lag1_stan                        21.4693      0.491     43.735      0.000      20.503      22.435
# ==============================================================================
# Omnibus:                        9.363   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               16.783
# Skew:                          -0.090   Prob(JB):                     0.000227
# Kurtosis:                       4.145   Cond. No.                         12.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sy = smf.ols('cci ~ total_cases_stan_start_start + stringency_index_stan_start_start + umsent_stan + cci_lag1_stan', df)
mo = sy.fit()
print(mo.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cci   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     1535.
# Date:                Sat, 12 Nov 2022   Prob (F-statistic):          4.76e-196
# Time:                        20:45:23   Log-Likelihood:                -958.49
# No. Observations:                 300   AIC:                             1927.
# Df Residuals:                     295   BIC:                             1945.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            95.4974      0.347    275.578      0.000      94.815      96.179
# total_cases_stan_start_start          4.6600      1.665      2.798      0.005       1.382       7.938
# stringency_index_stan_start_start     6.0637      2.641      2.296      0.022       0.867      11.261
# umsent_stan                           3.3238      0.520      6.396      0.000       2.301       4.347
# cci_lag1_stan                        21.4693      0.491     43.735      0.000      20.503      22.435
# ==============================================================================
# Omnibus:                        9.363   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               16.783
# Skew:                          -0.090   Prob(JB):                     0.000227
# Kurtosis:                       4.145   Cond. No.                         12.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sy2 = smf.ols('cci ~ total_cases_mean_start_start + stringency_index_mean_start_start + umsent_mean + cci_lag1_mean', df)
mo2 = sy2.fit()
print(mo2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cci   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.954
# Method:                 Least Squares   F-statistic:                     1535.
# Date:                Sat, 12 Nov 2022   Prob (F-statistic):          4.76e-196
# Time:                        20:35:01   Log-Likelihood:                -958.49
# No. Observations:                 300   AIC:                             1927.
# Df Residuals:                     295   BIC:                             1945.
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            95.4974      0.347    275.578      0.000      94.815      96.179
# total_cases_mean_start_start       1.414e-07   5.05e-08      2.798      0.005    4.19e-08    2.41e-07
# stringency_index_mean_start_start     0.1972      0.086      2.296      0.022       0.028       0.366
# umsent_mean                           0.2379      0.037      6.396      0.000       0.165       0.311
# cci_lag1_mean                         0.8736      0.020     43.735      0.000       0.834       0.913
# ==============================================================================
# Omnibus:                        9.363   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):               16.783
# Skew:                          -0.090   Prob(JB):                     0.000227
# Kurtosis:                       4.145   Cond. No.                     8.88e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.88e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
